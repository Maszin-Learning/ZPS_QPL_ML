# %%
import spectral_analysis as sa
import numpy as np

# %%
signal = sa.hermitian_pulse(1, [190, 196], 193, 0.1, 10000)
sa.plot(signal, start = 192.5, end = 193.5)
signal.fourier()
sa.plot(signal, start = -10, end = 10)

signal = sa.hermitian_pulse(1, [190, 196], 193, 0.1, 10000)
signal.Y = np.abs(signal.Y)
sa.plot(signal, start = 192.5, end = 193.5)
signal.fourier()
sa.plot(signal, start = -10, end = 10)
# Out:
# d:\Uniwerek\Lab\ZPS\ZPS_QPL_ML\spectral_analysis.py:1085: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
